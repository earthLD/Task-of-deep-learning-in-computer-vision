# %% [markdown]
# # Face recognition using neural network features

# %% [markdown]
# In this task, you have to construct face recognizer based on features extracted from the neural network. The task consists of two parts: image classification and video classification. In the first one you should classify distinct images and in the second one you will deal with short video sequences.

# %%
from keras.models import Model, Sequential
from keras.layers import Flatten, Dense, Activation
from keras.layers import Convolution2D, MaxPooling2D
from keras import backend as K
# Out:
# Using TensorFlow backend.

# %%
# %pylab inline
from matplotlib import pyplot as plt
import numpy as np
import cv2
import os
from copy import copy
from collections import Counter
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# First of all, you have you have to read the data. Run the cell below to unpack data.

# %%
#from get_data import unpack
#unpack('Face_Recognition_data.zip')

# %% [markdown]
# ### Reading data for image and video classification (1 point)

# %% [markdown]
# Implement function $\tt{load}$\_$\tt{image}$\_$\tt{data}$. It should return a tuple of 4 dictionaries: the first two are training images and labels, the second two are testing ones. The keys of the dictionaries are the names of the image files and the values are 3-dimensional numpy arrays (for images) or strings with the names (for labels).
#
# $\tt{dir}$\_$\tt{name}$ is the name of directory with data for image classification. If 'Face_Recofnition_data' directory is located in the same directory as this notebook, then the default value can be used.

# %%
def load_image_data(dir_name = 'Face_Recognition_data/image_classification'):
    """Your implementation"""
    import csv
    
    x_train={}
    y_train={}

    DATA_FOLDER = dir_name + '/train'
    csvfile_name = os.path.join(DATA_FOLDER, 'y_train.csv')
    imgfolder_name = os.path.join(DATA_FOLDER, 'images')
    with open(csvfile_name) as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')
        line_count = 0
        for key, item in csv_reader:
            if line_count == 0:
                pass
            else:
                y_train[key] = item
                imgfile_name = os.path.join(imgfolder_name, key)
                x_train[key] = plt.imread(imgfile_name)
            line_count += 1
            
            
    x_test={} 
    y_test={}
    
    DATA_FOLDER = dir_name + '/test'
    csvfile_name = os.path.join(DATA_FOLDER, 'y_test.csv')
    imgfolder_name = os.path.join(DATA_FOLDER, 'images')
    with open(csvfile_name) as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')
        line_count = 0
        for key, item in csv_reader:
            if line_count == 0:
                pass
            else:
                y_test[key] = item
                imgfile_name = os.path.join(imgfolder_name, key)
                x_test[key] = plt.imread(imgfile_name)
            line_count += 1

    
    return x_train, y_train, x_test, y_test

# %%
x_train, y_train, x_test, y_test = load_image_data()
print ('%d'%len(x_train), '\ttraining images')
print ('%d'%len(x_test), '\ttesting images')
# Out:
# 661 	training images
# 808 	testing images

# %%
def visualize(data, labels, function = lambda x:x[0], n_cols = 5, n_rows=1):
    figure(figsize = (3*n_cols,3*n_rows))
    
    # Fix iterator for python3 environment
    data_list = list(data.copy().keys())
    for n,i in enumerate(np.random.choice(data_list, size = n_cols*n_rows)):
    #for n,i in enumerate(np.random.choice(data.keys(), size = n_cols*n_rows)):
        plt.subplot(n_rows,n_cols,n+1)
        plt.axis('off')
        plt.imshow(function([data[i]]))
        plt.title(labels[i])
    plt.show()

# %% [markdown]
# That is how the data looks like.

# %%
visualize(x_train, y_train)
visualize(x_test, y_test)

# %% [markdown]
# Let us now read the video classification data, as well. You have to implement function to load video data.

# %% [markdown]
# Function $\tt{load}$\_$\tt{video}$\_$\tt{data}$ should also return a tuple of 4 dictionaries: the first two are training images and labels, the second two are testing videos and labels. The training data is in the same format as in image classification task. The keys of testing data and labels are video ids and the values are the lists of frames and the strings with names, respectively.

# %%
def load_video_data(dir_name = 'Face_Recognition_data/video_classification'):
    """Your implementation"""
    import csv
    
    video_train={}
    train_labels={}
    DATA_FOLDER = dir_name + '/train'
    csvfile_name = os.path.join(DATA_FOLDER, 'y_train.csv')
    imgfolder_name = os.path.join(DATA_FOLDER, 'images')
    with open(csvfile_name) as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')
        line_count = 0
        for key, item in csv_reader:
            if line_count == 0:
                pass
            else:
                train_labels[key] = item
                imgfile_name = os.path.join(imgfolder_name, key)
                video_train[key] = plt.imread(imgfile_name)
            line_count += 1
            
            
    video_test={} 
    test_labels={}
    DATA_FOLDER = dir_name + '/test'
    csvfile_name = os.path.join(DATA_FOLDER, 'y_test.csv')
    imgfolder_name = os.path.join(DATA_FOLDER, 'videos')
    with open(csvfile_name) as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')
        line_count = 0
        for key, item in csv_reader:
            if line_count == 0:
                pass
            else:
                test_labels[key] = item
                videofile_name = os.path.join(imgfolder_name, key)
                videofile_counts = len([name for name in os.listdir(videofile_name) if os.path.isfile(os.path.join(videofile_name, name))])
                video_test[key]=[]
                for idx in range(videofile_counts):
                    name = str(idx)+".jpg"
                    video_test[key].append(plt.imread(os.path.join(videofile_name, name)))
            line_count += 1
    
    
    return video_train, train_labels, video_test, test_labels

# %%
video_train, train_labels, video_test, test_labels = load_video_data()
print ('%d'%len(video_train), '\ttraining images')
print ('%d'%len(video_test), '\ttesting videos')
# Out:
# 729 	training images
# 70 	testing videos

# %%
visualize(video_train, train_labels)

# %%
visualize({i:video_test[i][1] for i in video_test}, test_labels)

# %% [markdown]
# ### Preprocessing (3 points)
# You have to implement preprocessing function in the cell below.
# Getting a list of images as an input the this function should detect the face on each image, find the facial keypoints () and then crop and normalize the image according to these keypoints. The output of this function is the list of images which contain only the aligned face and should be converted to the tensor of the shape $(N, 224, 224, 3)\ $ where $N$ is the length of the initial list. You can add extra arguments to the preprocess function if necessary (i.e. flag $\tt{is}$\_$\tt{video}$ to determine if the list of images is video sequence or not).
#
# For face detection and facial keypoint regression you can use your models from the previous tasks.

# %%
import cv2

def preprocess_imgs(imgs):
    """Your implementation"""
    images = []
    face_cascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")
    
    for image in imgs:
        h, w, ch  = image.shape
        faces = face_cascade.detectMultiScale(image, 1.3, 5)
                   
        if len(faces)<1:
            image = image[:, :,:]                        
        else:
            areas = [h * w for (x, y, h, w) in faces]
            index = np.argmax(areas)
            x,y,h,w = faces[index]
            image = image[x:x+h, y:y+w ,:]
            
        images.append(cv2.resize(image,(224,224), interpolation=cv2.INTER_LINEAR))    
                
    return images

# %% [markdown]
# #### Visualization of preprocessing

# %%
visualize(x_train, y_train, function = lambda x:preprocess_imgs(x)[0])

# %% [markdown]
# The neural network is already trained on the other face dataset. You should use this network as feature extractor to get descriptors of the faces. You can choose any hidden layer you need (or several layers) to extract features and any classification method.

# %%
import h5py
from keras.models import load_model
model = load_model('face_recognition_model.h5')
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1_1 (Conv2D)             (None, 224, 224, 64)      1792
# _________________________________________________________________
# conv1_2 (Conv2D)             (None, 224, 224, 64)      36928
# _________________________________________________________________
# pool1 (MaxPooling2D)         (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2_1 (Conv2D)             (None, 112, 112, 128)     73856
# _________________________________________________________________
# conv2_2 (Conv2D)             (None, 112, 112, 128)     147584
# _________________________________________________________________
# pool2 (MaxPooling2D)         (None, 56, 56, 128)       0
# _________________________________________________________________
# conv3_1 (Conv2D)             (None, 56, 56, 256)       295168
# _________________________________________________________________
# conv3_2 (Conv2D)             (None, 56, 56, 256)       590080
# _________________________________________________________________
# conv3_3 (Conv2D)             (None, 56, 56, 256)       590080
# _________________________________________________________________
# pool3 (MaxPooling2D)         (None, 28, 28, 256)       0
# _________________________________________________________________
# conv4_1 (Conv2D)             (None, 28, 28, 512)       1180160
# _________________________________________________________________
# conv4_2 (Conv2D)             (None, 28, 28, 512)       2359808
# _________________________________________________________________
# conv4_3 (Conv2D)             (None, 28, 28, 512)       2359808
# _________________________________________________________________
# pool4 (MaxPooling2D)         (None, 14, 14, 512)       0
# _________________________________________________________________
# conv5_1 (Conv2D)             (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv5_2 (Conv2D)             (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv5_3 (Conv2D)             (None, 14, 14, 512)       2359808
# _________________________________________________________________
# pool5 (MaxPooling2D)         (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc6 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc6/relu (Activation)        (None, 4096)              0
# _________________________________________________________________
# fc7 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# fc7/relu (Activation)        (None, 4096)              0
# _________________________________________________________________
# fc8 (Dense)                  (None, 500)               2048500
# _________________________________________________________________
# prob (Activation)            (None, 500)               0
# =================================================================
# Total params: 136,309,044
# Trainable params: 136,309,044
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Here is an example of using the network as feature extractor. The shape of input tensor has to be (n_images, 224, 224, 3), so you can input several images simultaneously and get their face descriptors of shape (n_images, n_components).

# %%
def get_layer_output(images, layer = 'fc6'):
    assert len(images.shape)==4, 'Wrong input dimentionality!'
    assert images.shape[1:]==(224,224,3), 'Wrong input shape!'
    
    network_output = model.get_layer(layer).output
    feature_extraction_model = Model(model.input, network_output)
    
    output = feature_extraction_model.predict(images)
    return output

# %%
img = cv2.resize(x_train['0.jpg'], (224,224)).reshape(1,224,224,3)
out = get_layer_output(img)
print (out.shape)
# Out:
# (1, 4096)

# %% [markdown]
# ### Training classifier (2 points)
#
#
# You have to implement class $\tt{Classifier}$ with methods $\tt{fit}$, $\tt{classify}$\_$\tt{images}$ and $\tt{classify}$\_$\tt{videos}$ in the cell below.
# The method $\tt{Classifier.fit}$ gets two dictionaries as input: train images and labels, and trains the classifier to predict the person shown on the image.
# $\tt{Classifier.classify}$\_$\tt{images}$ gets the dictionary of test images (with filenames as keys) as input and should return the dictionary of the predicted labels.
# $\tt{Classifier.classify}$\_$\tt{videos}$ is similar to the previous one, but gets the dictionary of test videos (with video as keys) as input.

# %% [markdown]
# To classify video you can combine the predictions for its frames any way you want (averaging, voting, etc.).
# If video classification takes too long you can use face detector not in all the frames but every few frames while preprocessing video frames.
# Besides, sometimes the face is hardly detected on the image and the frame in which the detector works wrong can add noise to the prediction. Hence, the result of the prediction without using such frames may be better.

# %%
from sklearn.neighbors import KNeighborsClassifier as kNN
from skimage.io import imread
import cv2
from os.path import join
from sklearn.preprocessing import LabelBinarizer
from keras.models import Sequential
from keras.layers import Dense, Dropout, BatchNormalization, Lambda
from keras import backend as K

class Classifier():
    def __init__(self, nn_model=None):
        self.clf = None

    def preprocess_images(self, images, keys):
        imgs = [images[k] for k in keys]
        faces = preprocess_imgs(imgs)
        return get_layer_output(np.array(faces))
    
    def fit_dnn(self, X, y):
        model = Sequential()
        model.add(Dense(1024, activation='relu', input_shape=[X.shape[-1]]))
        model.add(BatchNormalization())
        model.add(Dropout(0.25))
        model.add(Dense(512, activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.25))
        model.add(Dense(y.shape[-1]))
        model.add(Lambda(lambda x: K.tf.nn.softmax(x)))
        model.compile(optimizer='Adam', loss='categorical_crossentropy')
        model.fit(X, y, epochs=100)
        self.clf = model
    
    def fit(self, train_imgs, train_labels):
        keys = list(train_imgs.keys())
        y_raw = [train_labels[k] for k in keys]
        self.encoder = LabelBinarizer().fit(y_raw)
        y = self.encoder.transform(y_raw)
        X = self.preprocess_images(train_imgs, keys)
        self.fit_dnn(X, y)

    def classify_images(self, test_imgs):
        keys = list(test_imgs.keys())
        preds = self.clf.predict(self.preprocess_images(test_imgs, keys))
        names = self.encoder.inverse_transform(preds)
        return {k:n for k,n in zip(keys,names)}
       
    def classify_videos(self, test_video):
        keys = list(test_video.keys())
        y = {}
        for k in keys:
            imgs = test_video[k]
            faces = preprocess_imgs(imgs)
            descriptors = get_layer_output(np.array(faces))
            preds = self.clf.predict_proba(descriptors)
            sum_probs = preds.sum(axis=0)
            high_prob = np.argmax(sum_probs)
            sparse = np.zeros_like(sum_probs)
            sparse[high_prob] = 1
            name = self.encoder.inverse_transform(sparse[None])
            y[k] = name
        return y

# %% [markdown]
# Now we can build the classifier, fit it and use to predict the labels of testing images.

# %%
img_classifier = Classifier(model)
img_classifier.fit(x_train, y_train)
y_out = img_classifier.classify_images(x_test)
# Out:
# Epoch 1/100
# 661/661 [==============================] - 2s 3ms/step - loss: 3.1064
# Epoch 2/100
# 661/661 [==============================] - 0s 525us/step - loss: 0.6050
# Epoch 3/100
# 661/661 [==============================] - 0s 574us/step - loss: 0.2011
# Epoch 4/100
# 661/661 [==============================] - 0s 530us/step - loss: 0.1098
# Epoch 5/100
# 661/661 [==============================] - 0s 567us/step - loss: 0.0681
# Epoch 6/100
# 661/661 [==============================] - 0s 536us/step - loss: 0.0503
# Epoch 7/100
# 661/661 [==============================] - 0s 564us/step - loss: 0.0308
# Epoch 8/100
# 661/661 [==============================] - 0s 536us/step - loss: 0.0297
# Epoch 9/100
# 661/661 [==============================] - 0s 534us/step - loss: 0.0189
# Epoch 10/100
# 661/661 [==============================] - 0s 565us/step - loss: 0.0171
# Epoch 11/100
# 661/661 [==============================] - 0s 538us/step - loss: 0.0132
# Epoch 12/100
# 661/661 [==============================] - 0s 531us/step - loss: 0.0166
# Epoch 13/100
# 661/661 [==============================] - 0s 547us/step - loss: 0.0197
# Epoch 14/100
# 661/661 [==============================] - 0s 536us/step - loss: 0.0194
# Epoch 15/100
# 661/661 [==============================] - 0s 554us/step - loss: 0.0246
# Epoch 16/100
# 661/661 [==============================] - 0s 558us/step - loss: 0.0107
# Epoch 17/100
# 661/661 [==============================] - 0s 559us/step - loss: 0.0116
# Epoch 18/100
# 661/661 [==============================] - 0s 548us/step - loss: 0.0130
# Epoch 19/100
# 661/661 [==============================] - 0s 545us/step - loss: 0.0066
# Epoch 20/100
# 661/661 [==============================] - 0s 548us/step - loss: 0.0074
# Epoch 21/100
# 661/661 [==============================] - 0s 561us/step - loss: 0.0115
# Epoch 22/100
# 661/661 [==============================] - 0s 537us/step - loss: 0.0102
# Epoch 23/100
# 661/661 [==============================] - 0s 565us/step - loss: 0.0072
# Epoch 24/100
# 661/661 [==============================] - 0s 620us/step - loss: 0.0093
# Epoch 25/100
# 661/661 [==============================] - 0s 584us/step - loss: 0.0171
# Epoch 26/100
# 661/661 [==============================] - 0s 545us/step - loss: 0.0067
# Epoch 27/100
# 661/661 [==============================] - 0s 523us/step - loss: 0.0038
# Epoch 28/100
# 661/661 [==============================] - 0s 574us/step - loss: 0.0035
# Epoch 29/100
# 661/661 [==============================] - 0s 532us/step - loss: 0.0049
# Epoch 30/100
# 661/661 [==============================] - 0s 565us/step - loss: 0.0032
# Epoch 31/100
# 661/661 [==============================] - 0s 537us/step - loss: 0.0031
# Epoch 32/100
# 661/661 [==============================] - 0s 529us/step - loss: 0.0029
# Epoch 33/100
# 661/661 [==============================] - 0s 576us/step - loss: 0.0026
# Epoch 34/100
# 661/661 [==============================] - 0s 553us/step - loss: 0.0022
# Epoch 35/100
# 661/661 [==============================] - 0s 571us/step - loss: 0.0020
# Epoch 36/100
# 661/661 [==============================] - 0s 558us/step - loss: 0.0023
# Epoch 37/100
# 661/661 [==============================] - 0s 601us/step - loss: 0.0017
# Epoch 38/100
# 661/661 [==============================] - 0s 564us/step - loss: 0.0018
# Epoch 39/100
# 661/661 [==============================] - 0s 604us/step - loss: 0.0017
# Epoch 40/100
# 661/661 [==============================] - 0s 573us/step - loss: 0.0036
# Epoch 41/100
# 661/661 [==============================] - 0s 573us/step - loss: 0.0019
# Epoch 42/100
# 661/661 [==============================] - 0s 598us/step - loss: 0.0015
# Epoch 43/100
# 661/661 [==============================] - 0s 576us/step - loss: 0.0016
# Epoch 44/100
# 661/661 [==============================] - 0s 595us/step - loss: 0.0015 0s - loss: 0.001
# Epoch 45/100
# 661/661 [==============================] - 0s 551us/step - loss: 0.0014
# Epoch 46/100
# 661/661 [==============================] - 0s 609us/step - loss: 0.0013
# Epoch 47/100
# 661/661 [==============================] - 0s 582us/step - loss: 0.0014
# Epoch 48/100
# 661/661 [==============================] - 0s 587us/step - loss: 0.0012
# Epoch 49/100
# 661/661 [==============================] - 0s 593us/step - loss: 0.0010
# Epoch 50/100
# 661/661 [==============================] - 0s 575us/step - loss: 0.0013
# Epoch 51/100
# 661/661 [==============================] - 0s 579us/step - loss: 0.0014
# Epoch 52/100
# 661/661 [==============================] - 0s 573us/step - loss: 0.0014
# Epoch 53/100
# 661/661 [==============================] - 0s 595us/step - loss: 0.0012 0s - loss: 0
# Epoch 54/100
# 661/661 [==============================] - 0s 579us/step - loss: 0.0012
# Epoch 55/100
# 661/661 [==============================] - 0s 588us/step - loss: 0.0012
# Epoch 56/100
# 661/661 [==============================] - 0s 552us/step - loss: 9.0953e-04
# Epoch 57/100
# 661/661 [==============================] - 0s 581us/step - loss: 9.6871e-04
# Epoch 58/100
# 661/661 [==============================] - 0s 570us/step - loss: 9.0805e-04
# Epoch 59/100
# 661/661 [==============================] - 0s 573us/step - loss: 8.7287e-04
# Epoch 60/100
# 661/661 [==============================] - 0s 581us/step - loss: 8.0772e-04
# Epoch 61/100
# 661/661 [==============================] - 0s 572us/step - loss: 9.1341e-04
# Epoch 62/100
# 661/661 [==============================] - 0s 570us/step - loss: 9.5172e-04
# Epoch 63/100
# 661/661 [==============================] - 0s 561us/step - loss: 6.8877e-04
# Epoch 64/100
# 661/661 [==============================] - 0s 557us/step - loss: 7.2168e-04
# Epoch 65/100
# 661/661 [==============================] - 0s 573us/step - loss: 7.2298e-04
# Epoch 66/100
# 661/661 [==============================] - 0s 563us/step - loss: 7.4943e-04
# Epoch 67/100
# 661/661 [==============================] - 0s 578us/step - loss: 6.4170e-04
# Epoch 68/100
# 661/661 [==============================] - 0s 567us/step - loss: 7.9272e-04
# Epoch 69/100
# 661/661 [==============================] - 0s 578us/step - loss: 0.0016
# Epoch 70/100
# 661/661 [==============================] - 0s 578us/step - loss: 0.0225
# Epoch 71/100
# 661/661 [==============================] - 0s 581us/step - loss: 0.0559
# Epoch 72/100
# 661/661 [==============================] - 0s 579us/step - loss: 0.0758
# Epoch 73/100
# 661/661 [==============================] - 0s 578us/step - loss: 0.0754 0s - loss:
# Epoch 74/100
# 661/661 [==============================] - 0s 566us/step - loss: 0.1094
# Epoch 75/100
# 661/661 [==============================] - 0s 576us/step - loss: 0.1434
# Epoch 76/100
# 661/661 [==============================] - 0s 569us/step - loss: 0.1715
# Epoch 77/100
# 661/661 [==============================] - 0s 584us/step - loss: 0.1318
# Epoch 78/100
# 661/661 [==============================] - 0s 569us/step - loss: 0.0669
# Epoch 79/100
# 661/661 [==============================] - 0s 563us/step - loss: 0.0673
# Epoch 80/100
# 661/661 [==============================] - 0s 585us/step - loss: 0.0259
# Epoch 81/100
# 661/661 [==============================] - 0s 579us/step - loss: 0.0102
# Epoch 82/100
# 661/661 [==============================] - 0s 585us/step - loss: 0.0144
# Epoch 83/100
# 661/661 [==============================] - 0s 578us/step - loss: 0.0057
# Epoch 84/100
# 661/661 [==============================] - 0s 576us/step - loss: 0.0048
# Epoch 85/100
# 661/661 [==============================] - 0s 587us/step - loss: 0.0030
# Epoch 86/100
# 661/661 [==============================] - 0s 581us/step - loss: 0.0031
# Epoch 87/100
# 661/661 [==============================] - 0s 573us/step - loss: 0.0026
# Epoch 88/100
# 661/661 [==============================] - 0s 576us/step - loss: 0.0016
# Epoch 89/100
# 661/661 [==============================] - 0s 569us/step - loss: 0.0019
# Epoch 90/100
# 661/661 [==============================] - 0s 561us/step - loss: 0.0025
# Epoch 91/100
# 661/661 [==============================] - 0s 581us/step - loss: 0.0016
# Epoch 92/100
# 661/661 [==============================] - 0s 575us/step - loss: 0.0022
# Epoch 93/100
# 661/661 [==============================] - 0s 560us/step - loss: 0.0090
# Epoch 94/100
# 661/661 [==============================] - 0s 569us/step - loss: 0.0061
# Epoch 95/100
# 661/661 [==============================] - 0s 570us/step - loss: 0.0130
# Epoch 96/100
# 661/661 [==============================] - 0s 560us/step - loss: 0.0011
# Epoch 97/100
# 661/661 [==============================] - 0s 532us/step - loss: 0.0011
# Epoch 98/100
# 661/661 [==============================] - 0s 547us/step - loss: 0.0012
# Epoch 99/100
# 661/661 [==============================] - 0s 574us/step - loss: 0.0013
# Epoch 100/100
# 661/661 [==============================] - 0s 555us/step - loss: 0.0012

# %% [markdown]
# ### Image classification quality (2 points)
#
# Let us check the accuracy of your classification. To obtain 1 point for that rubric your implementation must have accuracy at least 0.90, to obtain 2 points — at least 0.95.

# %%
def check_test(output, gt):
    correct = 0.
    total = len(gt)
    for k, v in gt.items():
        if output[k] == v:
            correct += 1
    accuracy = correct / total

    return 'Classification accuracy is %.4f' % accuracy

# %%
print (check_test(y_out, y_test))
# Out:
# Classification accuracy is 0.9530

# %% [markdown]
# ### Video classification quality (2 points)
#
# Let us check the quality of video classification. To obtain 1 point for that rubric your implementation must have accuracy at least 0.80, to obtain 2 points — at least 0.85.

# %%
video_classifier = Classifier(model)
video_classifier.fit(video_train, train_labels)
# Out:
# Epoch 1/100
# 729/729 [==============================] - 2s 3ms/step - loss: 2.7847
# Epoch 2/100
# 729/729 [==============================] - 0s 551us/step - loss: 0.5765
# Epoch 3/100
# 729/729 [==============================] - 0s 542us/step - loss: 0.2890
# Epoch 4/100
# 729/729 [==============================] - 0s 567us/step - loss: 0.2018
# Epoch 5/100
# 729/729 [==============================] - 0s 547us/step - loss: 0.1347
# Epoch 6/100
# 729/729 [==============================] - 0s 567us/step - loss: 0.1419
# Epoch 7/100
# 729/729 [==============================] - 0s 551us/step - loss: 0.1109
# Epoch 8/100
# 729/729 [==============================] - 0s 555us/step - loss: 0.1061
# Epoch 9/100
# 729/729 [==============================] - 0s 573us/step - loss: 0.1025
# Epoch 10/100
# 729/729 [==============================] - 0s 539us/step - loss: 0.1004
# Epoch 11/100
# 729/729 [==============================] - 0s 566us/step - loss: 0.0887
# Epoch 12/100
# 729/729 [==============================] - 0s 565us/step - loss: 0.0969
# Epoch 13/100
# 729/729 [==============================] - 0s 557us/step - loss: 0.1040
# Epoch 14/100
# 729/729 [==============================] - 0s 562us/step - loss: 0.0793
# Epoch 15/100
# 729/729 [==============================] - 0s 559us/step - loss: 0.0885
# Epoch 16/100
# 729/729 [==============================] - 0s 571us/step - loss: 0.0731
# Epoch 17/100
# 729/729 [==============================] - 0s 582us/step - loss: 0.0497
# Epoch 18/100
# 729/729 [==============================] - 0s 561us/step - loss: 0.0512
# Epoch 19/100
# 729/729 [==============================] - 0s 561us/step - loss: 0.0353
# Epoch 20/100
# 729/729 [==============================] - 0s 579us/step - loss: 0.0662
# Epoch 21/100
# 729/729 [==============================] - 0s 582us/step - loss: 0.0550
# Epoch 22/100
# 729/729 [==============================] - 0s 577us/step - loss: 0.0549
# Epoch 23/100
# 729/729 [==============================] - 0s 576us/step - loss: 0.0563
# Epoch 24/100
# 729/729 [==============================] - 0s 565us/step - loss: 0.0608
# Epoch 25/100
# 729/729 [==============================] - 0s 585us/step - loss: 0.0290
# Epoch 26/100
# 729/729 [==============================] - 0s 563us/step - loss: 0.0277
# Epoch 27/100
# 729/729 [==============================] - 0s 557us/step - loss: 0.0272
# Epoch 28/100
# 729/729 [==============================] - 0s 584us/step - loss: 0.0180
# Epoch 29/100
# 729/729 [==============================] - 0s 571us/step - loss: 0.0297
# Epoch 30/100
# 729/729 [==============================] - 0s 579us/step - loss: 0.0241
# Epoch 31/100
# 729/729 [==============================] - 0s 566us/step - loss: 0.0216
# Epoch 32/100
# 729/729 [==============================] - 0s 562us/step - loss: 0.0116
# Epoch 33/100
# 729/729 [==============================] - 0s 562us/step - loss: 0.0245
# Epoch 34/100
# 729/729 [==============================] - 0s 546us/step - loss: 0.0344
# Epoch 35/100
# 729/729 [==============================] - 0s 607us/step - loss: 0.0142
# Epoch 36/100
# 729/729 [==============================] - 0s 598us/step - loss: 0.0506
# Epoch 37/100
# 729/729 [==============================] - 0s 555us/step - loss: 0.0833
# Epoch 38/100
# 729/729 [==============================] - 0s 616us/step - loss: 0.0498
# Epoch 39/100
# 729/729 [==============================] - 0s 608us/step - loss: 0.0356
# Epoch 40/100
# 729/729 [==============================] - 0s 591us/step - loss: 0.0379
# Epoch 41/100
# 729/729 [==============================] - 0s 573us/step - loss: 0.0443
# Epoch 42/100
# 729/729 [==============================] - 0s 582us/step - loss: 0.0428
# Epoch 43/100
# 729/729 [==============================] - 0s 532us/step - loss: 0.0801
# Epoch 44/100
# 729/729 [==============================] - 0s 534us/step - loss: 0.0315
# Epoch 45/100
# 729/729 [==============================] - 0s 540us/step - loss: 0.0256
# Epoch 46/100
# 729/729 [==============================] - 0s 553us/step - loss: 0.0597
# Epoch 47/100
# 729/729 [==============================] - 0s 551us/step - loss: 0.0693
# Epoch 48/100
# 729/729 [==============================] - 0s 534us/step - loss: 0.0502
# Epoch 49/100
# 729/729 [==============================] - 0s 530us/step - loss: 0.0383
# Epoch 50/100
# 729/729 [==============================] - 0s 594us/step - loss: 0.0276
# Epoch 51/100
# 729/729 [==============================] - 0s 605us/step - loss: 0.0154
# Epoch 52/100
# 729/729 [==============================] - 0s 587us/step - loss: 0.0092
# Epoch 53/100
# 729/729 [==============================] - 0s 601us/step - loss: 0.0279
# Epoch 54/100
# 729/729 [==============================] - 0s 558us/step - loss: 0.0242
# Epoch 55/100
# 729/729 [==============================] - 0s 560us/step - loss: 0.0187
# Epoch 56/100
# 729/729 [==============================] - 0s 590us/step - loss: 0.0246
# Epoch 57/100
# 729/729 [==============================] - 0s 588us/step - loss: 0.0123
# Epoch 58/100
# 729/729 [==============================] - 0s 579us/step - loss: 0.0099
# Epoch 59/100
# 729/729 [==============================] - 0s 595us/step - loss: 0.0206
# Epoch 60/100
# 729/729 [==============================] - 0s 615us/step - loss: 0.0751
# Epoch 61/100
# 729/729 [==============================] - 0s 610us/step - loss: 0.0310
# Epoch 62/100
# 729/729 [==============================] - 0s 569us/step - loss: 0.0396
# Epoch 63/100
# 729/729 [==============================] - 0s 532us/step - loss: 0.0272
# Epoch 64/100
# 729/729 [==============================] - 0s 558us/step - loss: 0.0223
# Epoch 65/100
# 729/729 [==============================] - 0s 531us/step - loss: 0.0104
# Epoch 66/100
# 729/729 [==============================] - 0s 546us/step - loss: 0.0311
# Epoch 67/100
# 729/729 [==============================] - 0s 542us/step - loss: 0.0223
# Epoch 68/100
# 729/729 [==============================] - 0s 532us/step - loss: 0.0116
# Epoch 69/100
# 729/729 [==============================] - 0s 542us/step - loss: 0.0045
# Epoch 70/100
# 729/729 [==============================] - 0s 538us/step - loss: 0.0035
# Epoch 71/100
# 729/729 [==============================] - 0s 546us/step - loss: 0.0045
# Epoch 72/100
# 729/729 [==============================] - 0s 536us/step - loss: 0.0087
# Epoch 73/100
# 729/729 [==============================] - 0s 539us/step - loss: 0.0075
# Epoch 74/100
# 729/729 [==============================] - 0s 545us/step - loss: 0.0025 0s - loss: 0.0
# Epoch 75/100
# 729/729 [==============================] - 0s 565us/step - loss: 0.0143
# Epoch 76/100
# 729/729 [==============================] - 0s 610us/step - loss: 0.0111
# Epoch 77/100
# 729/729 [==============================] - 0s 565us/step - loss: 0.0072
# Epoch 78/100
# 729/729 [==============================] - 0s 561us/step - loss: 0.0044
# Epoch 79/100
# 729/729 [==============================] - 0s 565us/step - loss: 0.0035
# Epoch 80/100
# 729/729 [==============================] - 0s 590us/step - loss: 0.0163
# Epoch 81/100
# 729/729 [==============================] - 0s 576us/step - loss: 0.0319
# Epoch 82/100
# 729/729 [==============================] - 0s 591us/step - loss: 0.0330
# Epoch 83/100
# 729/729 [==============================] - 0s 576us/step - loss: 0.0194
# Epoch 84/100
# 729/729 [==============================] - 0s 546us/step - loss: 0.0055
# Epoch 85/100
# 729/729 [==============================] - 0s 558us/step - loss: 0.0127
# Epoch 86/100
# 729/729 [==============================] - 0s 571us/step - loss: 0.0120
# Epoch 87/100
# 729/729 [==============================] - 0s 571us/step - loss: 0.0570
# Epoch 88/100
# 729/729 [==============================] - 0s 567us/step - loss: 0.0283
# Epoch 89/100
# 729/729 [==============================] - 0s 572us/step - loss: 0.0122
# Epoch 90/100
# 729/729 [==============================] - 0s 579us/step - loss: 0.0072
# Epoch 91/100
# 729/729 [==============================] - 0s 560us/step - loss: 0.0056
# Epoch 92/100
# 729/729 [==============================] - 0s 558us/step - loss: 0.0051
# Epoch 93/100
# 729/729 [==============================] - 0s 582us/step - loss: 0.0036
# Epoch 94/100
# 729/729 [==============================] - 0s 557us/step - loss: 0.0033
# Epoch 95/100
# 729/729 [==============================] - 0s 573us/step - loss: 0.0040
# Epoch 96/100
# 729/729 [==============================] - 0s 557us/step - loss: 0.0024
# Epoch 97/100
# 729/729 [==============================] - 0s 544us/step - loss: 0.0148
# Epoch 98/100
# 729/729 [==============================] - 0s 601us/step - loss: 0.0130
# Epoch 99/100
# 729/729 [==============================] - 0s 576us/step - loss: 0.0055
# Epoch 100/100
# 729/729 [==============================] - 0s 598us/step - loss: 0.0029

# %%
y_video_out = img_classifier.classify_images(video_train)

# %%
print (check_test(y_video_out, train_labels))
# Out:
# Classification accuracy is 0.2881
